# %%
# %%ai openai-chat:deepseek-chat -f code
# Bewerte den folgenden Code und füge deine Anmerkungen und Optimierungen als Kommentare direkt in den Code ein:
#
# import numpy as np
# import pandas as pd
# from lightweight_charts import JupyterChart
#
# # 1. Beispieldaten für Kerzen generieren
# dates = pd.date_range("2026-01-01", periods=100, freq="D")
# close = 100 + np.random.randn(100).cumsum()
# open_p = close + np.random.randn(100) * 0.5
# high = np.maximum(open_p, close) + np.random.rand(100) * 0.8
# low = np.minimum(open_p, close) - np.random.rand(100) * 0.8
#
# df = pd.DataFrame(
#     {"time": dates, "open": open_p, "high": high, "low": low, "close": close}
# )
#
# # 2. Interaktiven Chart in Zelle laden
# chart = JupyterChart(width=800, height=400)
# chart.set(df)
# chart.load()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'openai-chat:deepseek-chat -f code', 'Bewerte den folgenden Code und füge deine Anmerkungen und Optimierungen als Kommentare direkt in den Code ein:\n\nimport numpy as np\nimport pandas as pd\nfrom lightweight_charts import JupyterChart\n\n# 1. Beispieldaten für Kerzen generieren\ndates = pd.date_range("2026-01-01", periods=100, freq="D")\nclose = 100 + np.random.randn(100).cumsum()\nopen_p = close + np.random.randn(100) * 0.5\nhigh = np.maximum(open_p, close) + np.random.rand(100) * 0.8\nlow = np.minimum(open_p, close) - np.random.rand(100) * 0.8\n\ndf = pd.DataFrame(\n    {"time": dates, "open": open_p, "high": high, "low": low, "close": close}\n)\n\n# 2. Interaktiven Chart in Zelle laden\nchart = JupyterChart(width=800, height=400)\nchart.set(df)\nchart.load()\n')
# ...
